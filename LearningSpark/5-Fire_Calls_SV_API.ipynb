# %%
from pyspark.sql import SparkSession

# %%
spark = (SparkSession
         .builder
         .appName("Fire Department Calls for Service")
         .config("spark.sql.warehouse.dir", "./data/5-spark-warehouse")
         .getOrCreate())
# Out:
# 23/05/09 19:43:13 WARN Utils: Your hostname, wedivv-H110M-S2V resolves to a loopback address: 127.0.1.1; using 192.168.1.44 instead (on interface wlp5s0)
# 23/05/09 19:43:13 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/05/09 19:43:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
from sodapy import Socrata

# %%
client = Socrata("data.sfgov.org", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("nuek-vuh3", limit=25000)
type(results)
# Out:
# list

# %%
results
# Out:
# [{'call_number': '221210313',
#   'unit_id': 'E36',
#   'incident_number': '22054955',
#   'call_type': 'Outside Fire',
#   'call_date': '2022-05-01T00:00:00.000',
#   'watch_date': '2022-04-30T00:00:00.000',
#   'received_dttm': '2022-05-01T02:58:25.000',
#   'entry_dttm': '2022-05-01T02:59:15.000',
#   'dispatch_dttm': '2022-05-01T02:59:25.000',
#   'response_dttm': '2022-05-01T03:01:06.000',
#   'on_scene_dttm': '2022-05-01T03:02:27.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-05-01T03:05:00.000',
#   'address': 'GOUGH ST/GROVE ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94102',
#   'battalion': 'B02',
#   'station_area': '36',
#   'box': '3265',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Fire',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '2',
#   'supervisor_district': '5',
#   'neighborhoods_analysis_boundaries': 'Hayes Valley',
#   'rowid': '221210313-E36',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.42316555403964, 37.77781524520032]},
#   ':@computed_region_ajp5_b2md': '9'},
#  {'call_number': '220190150',
#   'unit_id': 'E29',
#   'incident_number': '22008871',
#   'call_type': 'Alarms',
#   'call_date': '2022-01-19T00:00:00.000',
#   'watch_date': '2022-01-18T00:00:00.000',
#   'received_dttm': '2022-01-19T01:42:12.000',
#   'entry_dttm': '2022-01-19T01:44:13.000',
#   'dispatch_dttm': '2022-01-19T01:44:28.000',
#   'response_dttm': '2022-01-19T01:46:47.000',
#   'on_scene_dttm': '2022-01-19T01:49:32.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-01-19T02:35:26.000',
#   'address': '100 Block of MISSISSIPPI ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94107',
#   'battalion': 'B03',
#   'station_area': '29',
#   'box': '2431',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '3',
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Potrero Hill',
#   'rowid': '220190150-E29',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.39469970274361, 37.76460987856451]},
#   ':@computed_region_ajp5_b2md': '26'},
#  {'call_number': '211233271',
#   'unit_id': 'T07',
#   'incident_number': '21053032',
#   'call_type': 'Alarms',
#   'call_date': '2021-05-03T00:00:00.000',
#   'watch_date': '2021-05-03T00:00:00.000',
#   'received_dttm': '2021-05-03T21:28:12.000',
#   'entry_dttm': '2021-05-03T21:28:12.000',
#   'dispatch_dttm': '2021-05-03T21:28:17.000',
#   'response_dttm': '2021-05-03T21:29:10.000',
#   'on_scene_dttm': '2021-05-03T21:32:15.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-05-03T21:38:09.000',
#   'address': '0 Block of HOFF ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94110',
#   'battalion': 'B02',
#   'station_area': '07',
#   'box': '5236',
#   'original_priority': 'A',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'TRUCK',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '2',
#   'supervisor_district': '9',
#   'neighborhoods_analysis_boundaries': 'Mission',
#   'rowid': '211233271-T07',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.42057572093252, 37.76418194637148]},
#   ':@computed_region_ajp5_b2md': '20'},
#  {'call_number': '212933533',
#   'unit_id': 'B02',
#   'incident_number': '21127914',
#   'call_type': 'Alarms',
#   'call_date': '2021-10-20T00:00:00.000',
#   'watch_date': '2021-10-20T00:00:00.000',
#   'received_dttm': '2021-10-20T22:08:47.000',
#   'entry_dttm': '2021-10-20T22:09:53.000',
#   'dispatch_dttm': '2021-10-20T22:10:07.000',
#   'response_dttm': '2021-10-20T22:11:55.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-10-20T22:25:52.000',
#   'address': '200 Block of JONES ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94102',
#   'battalion': 'B03',
#   'station_area': '03',
#   'box': '1456',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'CHIEF',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '3',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'rowid': '212933533-B02',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41243514072728, 37.78347684038771]},
#   ':@computed_region_ajp5_b2md': '36'},
#  {'call_number': '221202543',
#   'unit_id': 'E41',
#   'incident_number': '22054815',
#   'call_type': 'Alarms',
#   'call_date': '2022-04-30T00:00:00.000',
#   'watch_date': '2022-04-30T00:00:00.000',
#   'received_dttm': '2022-04-30T18:35:58.000',
#   'entry_dttm': '2022-04-30T18:37:28.000',
#   'dispatch_dttm': '2022-04-30T18:37:43.000',
#   'response_dttm': '2022-04-30T18:38:17.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-04-30T18:40:08.000',
#   'address': '1400 Block of FILBERT ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94109',
#   'battalion': 'B04',
#   'station_area': '16',
#   'box': '3146',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '4',
#   'fire_prevention_district': '4',
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Russian Hill',
#   'rowid': '221202543-E41',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.4233369425531, 37.799534868680034]},
#   ':@computed_region_ajp5_b2md': '32'},
#  {'call_number': '211232439',
#   'unit_id': 'B01',
#   'incident_number': '21052945',
#   'call_type': 'Alarms',
#   'call_date': '2021-05-03T00:00:00.000',
#   'watch_date': '2021-05-03T00:00:00.000',
#   'received_dttm': '2021-05-03T16:57:21.000',
#   'entry_dttm': '2021-05-03T16:58:39.000',
#   'dispatch_dttm': '2021-05-03T16:58:44.000',
#   'response_dttm': '2021-05-03T17:00:27.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-05-03T17:05:20.000',
#   'address': '500 Block of JONES ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94102',
#   'battalion': 'B01',
#   'station_area': '03',
#   'box': '1462',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'CHIEF',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '1',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'rowid': '211232439-B01',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41299723589606, 37.78626844171642]},
#   ':@computed_region_ajp5_b2md': '36'},
#  {'call_number': '211942517',
#   'unit_id': 'T03',
#   'incident_number': '21083057',
#   'call_type': 'Alarms',
#   'call_date': '2021-07-13T00:00:00.000',
#   'watch_date': '2021-07-13T00:00:00.000',
#   'received_dttm': '2021-07-13T16:50:10.000',
#   'entry_dttm': '2021-07-13T16:51:07.000',
#   'dispatch_dttm': '2021-07-13T16:51:17.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-07-13T16:54:45.000',
#   'address': '900 Block of VAN NESS AVE',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94109',
#   'battalion': 'B04',
#   'station_area': '03',
#   'box': '3162',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'TRUCK',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '2',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'rowid': '211942517-T03',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.42090696864193, 37.784067668377766]},
#   ':@computed_region_ajp5_b2md': '36'},
#  {'call_number': '212932758',
#   'unit_id': 'B01',
#   'incident_number': '21127810',
#   'call_type': 'Alarms',
#   'call_date': '2021-10-20T00:00:00.000',
#   'watch_date': '2021-10-20T00:00:00.000',
#   'received_dttm': '2021-10-20T17:46:09.000',
#   'entry_dttm': '2021-10-20T17:47:57.000',
#   'dispatch_dttm': '2021-10-20T17:48:05.000',
#   'response_dttm': '2021-10-20T17:49:54.000',
#   'on_scene_dttm': '2021-10-20T17:53:45.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-10-20T18:00:04.000',
#   'address': '0 Block of BEACH ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94133',
#   'battalion': 'B01',
#   'station_area': '28',
#   'box': '0939',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'CHIEF',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '1',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'North Beach',
#   'rowid': '212932758-B01',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.40987728293031, 37.808050096906186]},
#   ':@computed_region_ajp5_b2md': '23'},
#  {'call_number': '221201816',
#   'unit_id': 'T03',
#   'incident_number': '22054719',
#   'call_type': 'Structure Fire',
#   'call_date': '2022-04-30T00:00:00.000',
#   'watch_date': '2022-04-30T00:00:00.000',
#   'received_dttm': '2022-04-30T14:27:39.000',
#   'entry_dttm': '2022-04-30T14:28:53.000',
#   'dispatch_dttm': '2022-04-30T14:29:13.000',
#   'response_dttm': '2022-04-30T14:31:58.000',
#   'on_scene_dttm': '2022-04-30T14:31:58.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-04-30T14:46:15.000',
#   'address': 'MISSION ST/9TH ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B02',
#   'station_area': '36',
#   'box': '2336',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'TRUCK',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '2',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'rowid': '221201816-T03',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41471100467277, 37.77623051778801]},
#   ':@computed_region_ajp5_b2md': '34'},
#  {'call_number': '211941580',
#   'unit_id': 'SCRT4',
#   'incident_number': '21082970',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-07-13T00:00:00.000',
#   'watch_date': '2021-07-13T00:00:00.000',
#   'received_dttm': '2021-07-13T12:23:31.000',
#   'entry_dttm': '2021-07-13T12:28:02.000',
#   'dispatch_dttm': '2021-07-13T12:47:21.000',
#   'response_dttm': '2021-07-13T12:47:21.000',
#   'call_final_disposition': 'SFPD',
#   'available_dttm': '2021-07-13T12:48:46.000',
#   'address': '100 Block of VICENTE ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94127',
#   'battalion': 'B08',
#   'station_area': '39',
#   'box': '8612',
#   'original_priority': '1',
#   'priority': '1',
#   'final_priority': '2',
#   'als_unit': False,
#   'call_type_group': 'Non Life-threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'SUPPORT',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '8',
#   'supervisor_district': '7',
#   'neighborhoods_analysis_boundaries': 'West of Twin Peaks',
#   'rowid': '211941580-SCRT4',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.46750730609165, 37.73983589352891]},
#   ':@computed_region_ajp5_b2md': '41'},
#  {'call_number': '220181779',
#   'unit_id': '50',
#   'incident_number': '22008631',
#   'call_type': 'Other',
#   'call_date': '2022-01-18T00:00:00.000',
#   'watch_date': '2022-01-18T00:00:00.000',
#   'received_dttm': '2022-01-18T13:38:10.000',
#   'entry_dttm': '2022-01-18T13:38:47.000',
#   'dispatch_dttm': '2022-01-18T13:59:04.000',
#   'response_dttm': '2022-01-18T13:59:04.000',
#   'on_scene_dttm': '2022-01-18T13:59:04.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-01-18T15:55:14.000',
#   'address': '17-TH DE HARO ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B03',
#   'station_area': '29',
#   'box': '2355',
#   'original_priority': '2',
#   'priority': '2',
#   'final_priority': '2',
#   'als_unit': True,
#   'call_type_group': 'Non Life-threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '3.0',
#   'supervisor_district': '10',
#   'neighborhoods_analysis_boundaries': 'Mission Bay',
#   'rowid': '220181779-50',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.40113066801707, 37.764922583300844]},
#   ':@computed_region_ajp5_b2md': '4'},
#  {'call_number': '220111608',
#   'unit_id': 'E06',
#   'incident_number': '22005327',
#   'call_type': 'Alarms',
#   'call_date': '2022-01-11T00:00:00.000',
#   'watch_date': '2022-01-11T00:00:00.000',
#   'received_dttm': '2022-01-11T13:05:54.000',
#   'entry_dttm': '2022-01-11T13:07:03.000',
#   'dispatch_dttm': '2022-01-11T13:07:09.000',
#   'response_dttm': '2022-01-11T13:08:15.000',
#   'on_scene_dttm': '2022-01-11T13:09:19.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-01-11T13:16:05.000',
#   'address': '0 Block of SANCHEZ ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94114',
#   'battalion': 'B05',
#   'station_area': '06',
#   'box': '5131',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '2',
#   'supervisor_district': '8',
#   'neighborhoods_analysis_boundaries': 'Castro/Upper Market',
#   'rowid': '220111608-E06',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.43120487845243, 37.768462245901794]},
#   ':@computed_region_ajp5_b2md': '5'},
#  {'call_number': '220111597',
#   'unit_id': 'AM110',
#   'incident_number': '22005326',
#   'call_type': 'Medical Incident',
#   'call_date': '2022-01-11T00:00:00.000',
#   'watch_date': '2022-01-11T00:00:00.000',
#   'received_dttm': '2022-01-11T12:59:13.000',
#   'entry_dttm': '2022-01-11T13:02:48.000',
#   'dispatch_dttm': '2022-01-11T13:03:30.000',
#   'response_dttm': '2022-01-11T13:03:48.000',
#   'on_scene_dttm': '2022-01-11T13:11:24.000',
#   'transport_dttm': '2022-01-11T14:04:39.000',
#   'hospital_dttm': '2022-01-11T14:52:05.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2022-01-11T15:36:28.000',
#   'address': '100 Block of ADDISON ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94131',
#   'battalion': 'B06',
#   'station_area': '26',
#   'box': '8122',
#   'original_priority': '2',
#   'priority': '2',
#   'final_priority': '2',
#   'als_unit': False,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'PRIVATE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '6',
#   'supervisor_district': '8',
#   'neighborhoods_analysis_boundaries': 'Glen Park',
#   'rowid': '220111597-AM110',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.43239831371099, 37.73782181348269]},
#   ':@computed_region_ajp5_b2md': '10'},
#  {'call_number': '220111595',
#   'unit_id': 'E07',
#   'incident_number': '22005325',
#   'call_type': 'Outside Fire',
#   'call_date': '2022-01-11T00:00:00.000',
#   'watch_date': '2022-01-11T00:00:00.000',
#   'received_dttm': '2022-01-11T13:01:47.000',
#   'entry_dttm': '2022-01-11T13:01:47.000',
#   'dispatch_dttm': '2022-01-11T13:02:38.000',
#   'response_dttm': '2022-01-11T13:03:25.000',
#   'on_scene_dttm': '2022-01-11T13:05:37.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-01-11T13:07:41.000',
#   'address': 'FLORIDA ST/15TH ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B02',
#   'station_area': '29',
#   'box': '5221',
#   'original_priority': 'A',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Fire',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '2',
#   'supervisor_district': '9',
#   'neighborhoods_analysis_boundaries': 'Mission',
#   'rowid': '220111595-E07',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41158013454891, 37.76684138916838]},
#   ':@computed_region_ajp5_b2md': '20'},
#  {'call_number': '220181524',
#   'unit_id': 'E08',
#   'incident_number': '22008605',
#   'call_type': 'Alarms',
#   'call_date': '2022-01-18T00:00:00.000',
#   'watch_date': '2022-01-18T00:00:00.000',
#   'received_dttm': '2022-01-18T12:19:21.000',
#   'entry_dttm': '2022-01-18T12:22:54.000',
#   'dispatch_dttm': '2022-01-18T12:23:05.000',
#   'response_dttm': '2022-01-18T12:23:12.000',
#   'on_scene_dttm': '2022-01-18T12:24:41.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-01-18T12:27:19.000',
#   'address': '600 Block of BRYANT ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94107',
#   'battalion': 'B03',
#   'station_area': '08',
#   'box': '2242',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '3.0',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'rowid': '220181524-E08',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.39917886356567, 37.778682965266455]},
#   ':@computed_region_ajp5_b2md': '34'},
#  {'call_number': '221201435',
#   'unit_id': 'E41',
#   'incident_number': '22054664',
#   'call_type': 'Outside Fire',
#   'call_date': '2022-04-30T00:00:00.000',
#   'watch_date': '2022-04-30T00:00:00.000',
#   'received_dttm': '2022-04-30T12:32:37.000',
#   'entry_dttm': '2022-04-30T12:34:09.000',
#   'dispatch_dttm': '2022-04-30T12:34:15.000',
#   'response_dttm': '2022-04-30T12:35:20.000',
#   'on_scene_dttm': '2022-04-30T12:37:21.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-04-30T12:41:42.000',
#   'address': 'LARKIN ST/GREEN ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94109',
#   'battalion': 'B01',
#   'station_area': '41',
#   'box': '1631',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Fire',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '1',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Russian Hill',
#   'rowid': '221201435-E41',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.42050128567884, 37.79803346092744]},
#   ':@computed_region_ajp5_b2md': '32'},
#  {'call_number': '211941035',
#   'unit_id': 'T05',
#   'incident_number': '21082896',
#   'call_type': 'Citizen Assist / Service Call',
#   'call_date': '2021-07-13T00:00:00.000',
#   'watch_date': '2021-07-13T00:00:00.000',
#   'received_dttm': '2021-07-13T10:00:30.000',
#   'entry_dttm': '2021-07-13T10:01:59.000',
#   'dispatch_dttm': '2021-07-13T10:05:38.000',
#   'response_dttm': '2021-07-13T10:05:46.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-07-13T10:10:08.000',
#   'address': '0 Block of FRANKLIN ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94102',
#   'battalion': 'B02',
#   'station_area': '36',
#   'box': '3212',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'TRUCK',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '2',
#   'supervisor_district': '5',
#   'neighborhoods_analysis_boundaries': 'Hayes Valley',
#   'rowid': '211941035-T05',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.42074129455239, 37.77453627709375]},
#   ':@computed_region_ajp5_b2md': '9'},
#  {'call_number': '220181030',
#   'unit_id': 'B10',
#   'incident_number': '22008545',
#   'call_type': 'Alarms',
#   'call_date': '2022-01-18T00:00:00.000',
#   'watch_date': '2022-01-18T00:00:00.000',
#   'received_dttm': '2022-01-18T10:09:29.000',
#   'entry_dttm': '2022-01-18T10:11:19.000',
#   'dispatch_dttm': '2022-01-18T10:11:25.000',
#   'response_dttm': '2022-01-18T10:12:14.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-01-18T10:21:57.000',
#   'address': '700 Block of FLORIDA ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94110',
#   'battalion': 'B06',
#   'station_area': '07',
#   'box': '5451',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'CHIEF',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '6',
#   'supervisor_district': '9',
#   'neighborhoods_analysis_boundaries': 'Mission',
#   'rowid': '220181030-B10',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41082866531978, 37.75977151300213]},
#   ':@computed_region_ajp5_b2md': '20'},
#  {'call_number': '222091290',
#   'unit_id': 'T10',
#   'incident_number': '22096127',
#   'call_type': 'Alarms',
#   'call_date': '2022-07-28T00:00:00.000',
#   'watch_date': '2022-07-28T00:00:00.000',
#   'received_dttm': '2022-07-28T11:47:47.000',
#   'entry_dttm': '2022-07-28T11:49:52.000',
#   'dispatch_dttm': '2022-07-28T11:50:13.000',
#   'response_dttm': '2022-07-28T11:51:44.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-07-28T11:56:01.000',
#   'address': '300 Block of MASONIC AVE',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94118',
#   'battalion': 'B05',
#   'station_area': '21',
#   'box': '4462',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'TRUCK',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '5',
#   'supervisor_district': '5',
#   'neighborhoods_analysis_boundaries': 'Lone Mountain/USF',
#   'rowid': '222091290-T10',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.4468748150448, 37.778154438518655]},
#   ':@computed_region_ajp5_b2md': '18'},
#  {'call_number': '222091252',
#   'unit_id': 'SCRT3',
#   'incident_number': '22096119',
#   'call_type': 'Other',
#   'call_date': '2022-07-28T00:00:00.000',
#   'watch_date': '2022-07-28T00:00:00.000',
#   'received_dttm': '2022-07-28T11:39:25.000',
#   'entry_dttm': '2022-07-28T11:39:25.000',
#   'dispatch_dttm': '2022-07-28T11:39:50.000',
#   'call_final_disposition': 'Cancelled',
#   'available_dttm': '2022-07-28T11:40:38.000',
#   'address': '900 Block of MARKET ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B01',
#   'station_area': '01',
#   'box': '2247',
#   'original_priority': 'A',
#   'priority': '1',
#   'final_priority': '2',
#   'als_unit': False,
#   'number_of_alarms': '1',
#   'unit_type': 'SUPPORT',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '3',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'rowid': '222091252-SCRT3',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.40842111692173, 37.78356993869201]},
#   ':@computed_region_ajp5_b2md': '34'},
#  {'call_number': '221200830',
#   'unit_id': 'E03',
#   'incident_number': '22054584',
#   'call_type': 'Alarms',
#   'call_date': '2022-04-30T00:00:00.000',
#   'watch_date': '2022-04-30T00:00:00.000',
#   'received_dttm': '2022-04-30T09:14:00.000',
#   'entry_dttm': '2022-04-30T09:15:34.000',
#   'dispatch_dttm': '2022-04-30T09:15:43.000',
#   'response_dttm': '2022-04-30T09:18:05.000',
#   'on_scene_dttm': '2022-04-30T09:19:35.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-04-30T09:31:26.000',
#   'address': '200 Block of GOLDEN GATE AVE',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94102',
#   'battalion': 'B02',
#   'station_area': '03',
#   'box': '1548',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '2',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'rowid': '221200830-E03',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41510513501383, 37.78176090810061]},
#   ':@computed_region_ajp5_b2md': '36'},
#  {'call_number': '220180731',
#   'unit_id': '76',
#   'incident_number': '22008514',
#   'call_type': 'Medical Incident',
#   'call_date': '2022-01-18T00:00:00.000',
#   'watch_date': '2022-01-18T00:00:00.000',
#   'received_dttm': '2022-01-18T08:42:03.000',
#   'entry_dttm': '2022-01-18T08:43:28.000',
#   'dispatch_dttm': '2022-01-18T08:47:08.000',
#   'response_dttm': '2022-01-18T08:47:15.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2022-01-18T08:50:15.000',
#   'address': '0 Block of CARL ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94117',
#   'battalion': 'B05',
#   'station_area': '12',
#   'box': '5199',
#   'original_priority': '2',
#   'priority': '2',
#   'final_priority': '2',
#   'als_unit': True,
#   'call_type_group': 'Non Life-threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '5',
#   'supervisor_district': '5',
#   'neighborhoods_analysis_boundaries': 'Haight Ashbury',
#   'rowid': '220180731-76',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.44890193700888, 37.76599035911472]},
#   ':@computed_region_ajp5_b2md': '3'},
#  {'call_number': '211230557',
#   'unit_id': 'E08',
#   'incident_number': '21052693',
#   'call_type': 'Alarms',
#   'call_date': '2021-05-03T00:00:00.000',
#   'watch_date': '2021-05-03T00:00:00.000',
#   'received_dttm': '2021-05-03T08:10:53.000',
#   'entry_dttm': '2021-05-03T08:12:23.000',
#   'dispatch_dttm': '2021-05-03T08:12:30.000',
#   'response_dttm': '2021-05-03T08:15:05.000',
#   'on_scene_dttm': '2021-05-03T08:16:37.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-05-03T08:28:56.000',
#   'address': '100 Block of BERRY ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94158',
#   'battalion': 'B03',
#   'station_area': '08',
#   'box': '2171',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '3',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Mission Bay',
#   'rowid': '211230557-E08',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.39218945055315, 37.776631385410525]},
#   ':@computed_region_ajp5_b2md': '4'},
#  {'call_number': '212930834',
#   'unit_id': 'E02',
#   'incident_number': '21127608',
#   'call_type': 'Alarms',
#   'call_date': '2021-10-20T00:00:00.000',
#   'watch_date': '2021-10-20T00:00:00.000',
#   'received_dttm': '2021-10-20T08:56:13.000',
#   'entry_dttm': '2021-10-20T08:57:38.000',
#   'dispatch_dttm': '2021-10-20T08:57:51.000',
#   'response_dttm': '2021-10-20T08:57:58.000',
#   'on_scene_dttm': '2021-10-20T09:02:36.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-10-20T09:09:37.000',
#   'address': '500-501 TAYLOR ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94102',
#   'battalion': 'B01',
#   'station_area': '03',
#   'box': '1451',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '1.0',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'rowid': '212930834-E02',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41148097975834, 37.787114830341956]},
#   ':@computed_region_ajp5_b2md': '36'},
#  {'call_number': '211940163',
#   'unit_id': '73',
#   'incident_number': '21082786',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-07-13T00:00:00.000',
#   'watch_date': '2021-07-12T00:00:00.000',
#   'received_dttm': '2021-07-13T02:27:46.000',
#   'entry_dttm': '2021-07-13T02:30:19.000',
#   'dispatch_dttm': '2021-07-13T02:30:47.000',
#   'response_dttm': '2021-07-13T02:30:59.000',
#   'on_scene_dttm': '2021-07-13T02:42:16.000',
#   'transport_dttm': '2021-07-13T02:51:27.000',
#   'hospital_dttm': '2021-07-13T02:55:34.000',
#   'call_final_disposition': 'Code 3 Transport',
#   'available_dttm': '2021-07-13T03:42:32.000',
#   'address': '100 Block of 3RD ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B03',
#   'station_area': '01',
#   'box': '2177',
#   'original_priority': '2',
#   'priority': '2',
#   'final_priority': '2',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '3',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Financial District/South Beach',
#   'rowid': '211940163-73',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.40093057593437, 37.785468868780875]},
#   ':@computed_region_ajp5_b2md': '8'},
#  {'call_number': '211940150',
#   'unit_id': 'E07',
#   'incident_number': '21082785',
#   'call_type': 'Traffic Collision',
#   'call_date': '2021-07-13T00:00:00.000',
#   'watch_date': '2021-07-12T00:00:00.000',
#   'received_dttm': '2021-07-13T02:14:37.000',
#   'entry_dttm': '2021-07-13T02:14:37.000',
#   'dispatch_dttm': '2021-07-13T02:14:54.000',
#   'response_dttm': '2021-07-13T02:16:29.000',
#   'on_scene_dttm': '2021-07-13T02:18:18.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-07-13T02:33:19.000',
#   'address': '2600 Block of HARRISON ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94110',
#   'battalion': 'B06',
#   'station_area': '07',
#   'box': '0545',
#   'original_priority': 'B',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Non Life-threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '6.0',
#   'supervisor_district': '9',
#   'neighborhoods_analysis_boundaries': 'Mission',
#   'rowid': '211940150-E07',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41212257930248, 37.755031422190974]},
#   ':@computed_region_ajp5_b2md': '20'},
#  {'call_number': '211940150',
#   'unit_id': '77',
#   'incident_number': '21082785',
#   'call_type': 'Traffic Collision',
#   'call_date': '2021-07-13T00:00:00.000',
#   'watch_date': '2021-07-12T00:00:00.000',
#   'received_dttm': '2021-07-13T02:14:37.000',
#   'entry_dttm': '2021-07-13T02:14:37.000',
#   'dispatch_dttm': '2021-07-13T02:14:54.000',
#   'response_dttm': '2021-07-13T02:15:04.000',
#   'on_scene_dttm': '2021-07-13T02:19:26.000',
#   'transport_dttm': '2021-07-13T02:51:42.000',
#   'hospital_dttm': '2021-07-13T02:57:45.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-07-13T03:44:58.000',
#   'address': '2600 Block of HARRISON ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94110',
#   'battalion': 'B06',
#   'station_area': '07',
#   'box': '0545',
#   'original_priority': 'B',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Non Life-threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '6.0',
#   'supervisor_district': '9',
#   'neighborhoods_analysis_boundaries': 'Mission',
#   'rowid': '211940150-77',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41212257930248, 37.755031422190974]},
#   ':@computed_region_ajp5_b2md': '20'},
#  {'call_number': '211940174',
#   'unit_id': '62',
#   'incident_number': '21082787',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-07-13T00:00:00.000',
#   'watch_date': '2021-07-12T00:00:00.000',
#   'received_dttm': '2021-07-13T02:48:01.000',
#   'entry_dttm': '2021-07-13T02:50:13.000',
#   'dispatch_dttm': '2021-07-13T02:53:06.000',
#   'response_dttm': '2021-07-13T02:54:19.000',
#   'on_scene_dttm': '2021-07-13T03:08:39.000',
#   'transport_dttm': '2021-07-13T03:29:15.000',
#   'hospital_dttm': '2021-07-13T03:37:07.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-07-13T04:19:25.000',
#   'address': '500 Block of SOUTH VAN NESS AVE',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94110',
#   'battalion': 'B02',
#   'station_area': '07',
#   'box': '5246',
#   'original_priority': '2',
#   'priority': '2',
#   'final_priority': '2',
#   'als_unit': True,
#   'call_type_group': 'Non Life-threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '2',
#   'supervisor_district': '9',
#   'neighborhoods_analysis_boundaries': 'Mission',
#   'rowid': '211940174-62',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41747849146768, 37.76437320966664]},
#   ':@computed_region_ajp5_b2md': '20'},
#  {'call_number': '221200301',
#   'unit_id': 'T11',
#   'incident_number': '22054509',
#   'call_type': 'Alarms',
#   'call_date': '2022-04-30T00:00:00.000',
#   'watch_date': '2022-04-29T00:00:00.000',
#   'received_dttm': '2022-04-30T02:55:25.000',
#   'entry_dttm': '2022-04-30T02:57:52.000',
#   'dispatch_dttm': '2022-04-30T02:58:00.000',
#   'response_dttm': '2022-04-30T03:00:17.000',
#   'on_scene_dttm': '2022-04-30T03:02:22.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-04-30T03:10:16.000',
#   'address': '1000 Block of CHURCH ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94114',
#   'battalion': 'B06',
#   'station_area': '11',
#   'box': '5467',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'TRUCK',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '6',
#   'supervisor_district': '8',
#   'neighborhoods_analysis_boundaries': 'Noe Valley',
#   'rowid': '221200301-T11',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.42759040963105, 37.75409838123123]},
#   ':@computed_region_ajp5_b2md': '22'},
#  {'call_number': '221200301',
#   'unit_id': 'B06',
#   'incident_number': '22054509',
#   'call_type': 'Alarms',
#   'call_date': '2022-04-30T00:00:00.000',
#   'watch_date': '2022-04-29T00:00:00.000',
#   'received_dttm': '2022-04-30T02:55:25.000',
#   'entry_dttm': '2022-04-30T02:57:52.000',
#   'dispatch_dttm': '2022-04-30T02:58:00.000',
#   'response_dttm': '2022-04-30T03:01:14.000',
#   'on_scene_dttm': '2022-04-30T03:02:50.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-04-30T03:11:18.000',
#   'address': '1000 Block of CHURCH ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94114',
#   'battalion': 'B06',
#   'station_area': '11',
#   'box': '5467',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'CHIEF',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '6',
#   'supervisor_district': '8',
#   'neighborhoods_analysis_boundaries': 'Noe Valley',
#   'rowid': '221200301-B06',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.42759040963105, 37.75409838123123]},
#   ':@computed_region_ajp5_b2md': '22'},
#  {'call_number': '221200301',
#   'unit_id': 'E11',
#   'incident_number': '22054509',
#   'call_type': 'Alarms',
#   'call_date': '2022-04-30T00:00:00.000',
#   'watch_date': '2022-04-29T00:00:00.000',
#   'received_dttm': '2022-04-30T02:55:25.000',
#   'entry_dttm': '2022-04-30T02:57:52.000',
#   'dispatch_dttm': '2022-04-30T02:58:00.000',
#   'response_dttm': '2022-04-30T02:59:52.000',
#   'on_scene_dttm': '2022-04-30T03:01:46.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-04-30T03:10:45.000',
#   'address': '1000 Block of CHURCH ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94114',
#   'battalion': 'B06',
#   'station_area': '11',
#   'box': '5467',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '6',
#   'supervisor_district': '8',
#   'neighborhoods_analysis_boundaries': 'Noe Valley',
#   'rowid': '221200301-E11',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.42759040963105, 37.75409838123123]},
#   ':@computed_region_ajp5_b2md': '22'},
#  {'call_number': '211940032',
#   'unit_id': 'T14',
#   'incident_number': '21082774',
#   'call_type': 'Alarms',
#   'call_date': '2021-07-13T00:00:00.000',
#   'watch_date': '2021-07-12T00:00:00.000',
#   'received_dttm': '2021-07-13T00:31:53.000',
#   'entry_dttm': '2021-07-13T00:34:05.000',
#   'dispatch_dttm': '2021-07-13T00:34:12.000',
#   'response_dttm': '2021-07-13T00:35:49.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-07-13T00:39:58.000',
#   'address': '600 Block of 16TH AVE',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94118',
#   'battalion': 'B07',
#   'station_area': '31',
#   'box': '7155',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'TRUCK',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '7',
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Outer Richmond',
#   'rowid': '211940032-T14',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.47468461641205, 37.77581222755014]},
#   ':@computed_region_ajp5_b2md': '29'},
#  {'call_number': '211230166',
#   'unit_id': '59',
#   'incident_number': '21052638',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-05-03T00:00:00.000',
#   'watch_date': '2021-05-02T00:00:00.000',
#   'received_dttm': '2021-05-03T02:56:45.000',
#   'entry_dttm': '2021-05-03T02:56:45.000',
#   'dispatch_dttm': '2021-05-03T02:57:17.000',
#   'response_dttm': '2021-05-03T02:57:24.000',
#   'on_scene_dttm': '2021-05-03T02:59:15.000',
#   'transport_dttm': '2021-05-03T03:04:39.000',
#   'hospital_dttm': '2021-05-03T03:06:30.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-05-03T03:45:41.000',
#   'address': '1800 Block of WALLER ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94122',
#   'battalion': 'B05',
#   'station_area': '12',
#   'box': '4552',
#   'original_priority': 'B',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '5',
#   'supervisor_district': '5',
#   'neighborhoods_analysis_boundaries': 'Golden Gate Park',
#   'rowid': '211230166-59',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.45431162017051, 37.76815416294525]},
#   ':@computed_region_ajp5_b2md': '12'},
#  {'call_number': '211230166',
#   'unit_id': 'E12',
#   'incident_number': '21052638',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-05-03T00:00:00.000',
#   'watch_date': '2021-05-02T00:00:00.000',
#   'received_dttm': '2021-05-03T02:56:45.000',
#   'entry_dttm': '2021-05-03T02:56:45.000',
#   'dispatch_dttm': '2021-05-03T02:57:17.000',
#   'response_dttm': '2021-05-03T02:59:00.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-05-03T03:02:17.000',
#   'address': '1800 Block of WALLER ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94122',
#   'battalion': 'B05',
#   'station_area': '12',
#   'box': '4552',
#   'original_priority': 'B',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '5',
#   'supervisor_district': '5',
#   'neighborhoods_analysis_boundaries': 'Golden Gate Park',
#   'rowid': '211230166-E12',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.45431162017051, 37.76815416294525]},
#   ':@computed_region_ajp5_b2md': '12'},
#  {'call_number': '211230167',
#   'unit_id': '77',
#   'incident_number': '21052639',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-05-03T00:00:00.000',
#   'watch_date': '2021-05-02T00:00:00.000',
#   'received_dttm': '2021-05-03T02:55:59.000',
#   'entry_dttm': '2021-05-03T02:58:39.000',
#   'dispatch_dttm': '2021-05-03T02:59:43.000',
#   'response_dttm': '2021-05-03T02:59:49.000',
#   'on_scene_dttm': '2021-05-03T03:06:28.000',
#   'transport_dttm': '2021-05-03T03:17:38.000',
#   'hospital_dttm': '2021-05-03T03:23:45.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-05-03T03:55:19.000',
#   'address': 'HYDE ST/GROVE ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B02',
#   'station_area': '36',
#   'box': '1552',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '2',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'rowid': '211230167-77',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41474122302185, 37.77871942885321]},
#   ':@computed_region_ajp5_b2md': '36'},
#  {'call_number': '211230167',
#   'unit_id': 'E03',
#   'incident_number': '21052639',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-05-03T00:00:00.000',
#   'watch_date': '2021-05-02T00:00:00.000',
#   'received_dttm': '2021-05-03T02:55:59.000',
#   'entry_dttm': '2021-05-03T02:58:39.000',
#   'dispatch_dttm': '2021-05-03T02:59:43.000',
#   'response_dttm': '2021-05-03T03:01:45.000',
#   'on_scene_dttm': '2021-05-03T03:05:18.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-05-03T03:09:21.000',
#   'address': 'HYDE ST/GROVE ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B02',
#   'station_area': '36',
#   'box': '1552',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '2',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'rowid': '211230167-E03',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41474122302185, 37.77871942885321]},
#   ':@computed_region_ajp5_b2md': '36'},
#  {'call_number': '210391341',
#   'unit_id': 'B02',
#   'incident_number': '21017620',
#   'call_type': 'Alarms',
#   'call_date': '2021-02-08T00:00:00.000',
#   'watch_date': '2021-02-08T00:00:00.000',
#   'received_dttm': '2021-02-08T11:45:49.000',
#   'entry_dttm': '2021-02-08T11:47:29.000',
#   'dispatch_dttm': '2021-02-08T11:48:12.000',
#   'response_dttm': '2021-02-08T11:49:34.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-02-08T11:51:59.000',
#   'address': '100 Block of EDDY ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94102',
#   'battalion': 'B03',
#   'station_area': '03',
#   'box': '1453',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'CHIEF',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '3',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'rowid': '210391341-B02',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41011948345108, 37.78419090478903]},
#   ':@computed_region_ajp5_b2md': '36'},
#  {'call_number': '222090209',
#   'unit_id': 'T14',
#   'incident_number': '22095985',
#   'call_type': 'Other',
#   'call_date': '2022-07-28T00:00:00.000',
#   'watch_date': '2022-07-27T00:00:00.000',
#   'received_dttm': '2022-07-28T02:57:56.000',
#   'entry_dttm': '2022-07-28T02:57:56.000',
#   'dispatch_dttm': '2022-07-28T02:58:30.000',
#   'response_dttm': '2022-07-28T03:00:42.000',
#   'on_scene_dttm': '2022-07-28T03:02:57.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-07-28T03:16:45.000',
#   'address': '6100 Block of GEARY BL',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94121',
#   'battalion': 'B07',
#   'station_area': '14',
#   'box': '7213',
#   'original_priority': 'C',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'TRUCK',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '7.0',
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Outer Richmond',
#   'rowid': '222090209-T14',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.48527495541484, 37.78013450549825]},
#   ':@computed_region_ajp5_b2md': '29'},
#  {'call_number': '212930249',
#   'unit_id': 'E14',
#   'incident_number': '21127530',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-10-20T00:00:00.000',
#   'watch_date': '2021-10-19T00:00:00.000',
#   'received_dttm': '2021-10-20T02:46:13.000',
#   'entry_dttm': '2021-10-20T02:46:58.000',
#   'dispatch_dttm': '2021-10-20T02:47:10.000',
#   'response_dttm': '2021-10-20T02:49:17.000',
#   'on_scene_dttm': '2021-10-20T02:52:09.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-10-20T03:06:01.000',
#   'address': '200 Block of EL CAMINO DEL MAR',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94121',
#   'battalion': 'B07',
#   'station_area': '14',
#   'box': '7215',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '7',
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Seacliff',
#   'rowid': '212930249-E14',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.4858252679559, 37.78764160195054]},
#   ':@computed_region_ajp5_b2md': '33'},
#  {'call_number': '222090139',
#   'unit_id': 'B02',
#   'incident_number': '22095973',
#   'call_type': 'Alarms',
#   'call_date': '2022-07-28T00:00:00.000',
#   'watch_date': '2022-07-27T00:00:00.000',
#   'received_dttm': '2022-07-28T02:00:16.000',
#   'entry_dttm': '2022-07-28T02:02:40.000',
#   'dispatch_dttm': '2022-07-28T02:02:51.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2022-07-28T02:04:49.000',
#   'address': '0 Block of TAYLOR ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94102',
#   'battalion': 'B03',
#   'station_area': '01',
#   'box': '1454',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'CHIEF',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '3',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'Tenderloin',
#   'rowid': '222090139-B02',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41068795650901, 37.78248520640453]},
#   ':@computed_region_ajp5_b2md': '36'},
#  {'call_number': '212971884',
#   'unit_id': 'E14',
#   'incident_number': '21129868',
#   'call_type': 'Alarms',
#   'call_date': '2021-10-24T00:00:00.000',
#   'watch_date': '2021-10-24T00:00:00.000',
#   'received_dttm': '2021-10-24T13:22:29.000',
#   'entry_dttm': '2021-10-24T13:24:05.000',
#   'dispatch_dttm': '2021-10-24T13:24:10.000',
#   'response_dttm': '2021-10-24T13:25:09.000',
#   'on_scene_dttm': '2021-10-24T13:27:51.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-10-24T13:30:00.000',
#   'address': '600 Block of 24TH AV',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94121',
#   'battalion': 'B07',
#   'station_area': '14',
#   'box': '7176',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '7.0',
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Outer Richmond',
# ...
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Chinatown',
#   'rowid': '211813252-E02',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.40864512740546, 37.79810807456255]},
#   ':@computed_region_ajp5_b2md': '6'},
#  {'call_number': '211813252',
#   'unit_id': 'AM120',
#   'incident_number': '21077731',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:45:45.000',
#   'entry_dttm': '2021-06-30T20:47:31.000',
#   'dispatch_dttm': '2021-06-30T20:47:42.000',
#   'call_final_disposition': 'Code 3 Transport',
#   'available_dttm': '2021-06-30T20:49:15.000',
#   'address': '1300 Block of STOCKTON ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94133',
#   'battalion': 'B01',
#   'station_area': '02',
#   'box': '1333',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'PRIVATE',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '1',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Chinatown',
#   'rowid': '211813252-AM120',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.40864512740546, 37.79810807456255]},
#   ':@computed_region_ajp5_b2md': '6'},
#  {'call_number': '211813252',
#   'unit_id': '95',
#   'incident_number': '21077731',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:45:45.000',
#   'entry_dttm': '2021-06-30T20:47:31.000',
#   'dispatch_dttm': '2021-06-30T20:48:44.000',
#   'response_dttm': '2021-06-30T20:48:47.000',
#   'on_scene_dttm': '2021-06-30T20:51:25.000',
#   'transport_dttm': '2021-06-30T21:14:37.000',
#   'hospital_dttm': '2021-06-30T21:20:08.000',
#   'call_final_disposition': 'Code 3 Transport',
#   'available_dttm': '2021-06-30T22:14:37.000',
#   'address': '1300 Block of STOCKTON ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94133',
#   'battalion': 'B01',
#   'station_area': '02',
#   'box': '1333',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '1',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'Chinatown',
#   'rowid': '211813252-95',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.40864512740546, 37.79810807456255]},
#   ':@computed_region_ajp5_b2md': '6'},
#  {'call_number': '211813245',
#   'unit_id': '73',
#   'incident_number': '21077730',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:44:18.000',
#   'entry_dttm': '2021-06-30T20:44:18.000',
#   'dispatch_dttm': '2021-06-30T20:45:02.000',
#   'response_dttm': '2021-06-30T20:45:06.000',
#   'on_scene_dttm': '2021-06-30T20:54:02.000',
#   'transport_dttm': '2021-06-30T21:18:05.000',
#   'hospital_dttm': '2021-06-30T21:26:44.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-06-30T22:58:21.000',
#   'address': '400 Block of GENEVA AVE',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94112',
#   'battalion': 'B09',
#   'station_area': '15',
#   'box': '8319',
#   'original_priority': 'B',
#   'priority': '2',
#   'final_priority': '2',
#   'als_unit': True,
#   'call_type_group': 'Non Life-threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '9',
#   'supervisor_district': '11',
#   'neighborhoods_analysis_boundaries': 'Outer Mission',
#   'rowid': '211813245-73',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.44713618372195, 37.72103513607573]},
#   ':@computed_region_ajp5_b2md': '28'},
#  {'call_number': '211813229',
#   'unit_id': '95',
#   'incident_number': '21077729',
#   'call_type': 'Traffic Collision',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:39:24.000',
#   'entry_dttm': '2021-06-30T20:39:24.000',
#   'dispatch_dttm': '2021-06-30T20:39:42.000',
#   'response_dttm': '2021-06-30T20:39:45.000',
#   'on_scene_dttm': '2021-06-30T20:43:22.000',
#   'call_final_disposition': 'Unable to Locate',
#   'available_dttm': '2021-06-30T20:44:19.000',
#   'address': '7TH ST/MISSION ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B02',
#   'station_area': '01',
#   'box': '2315',
#   'original_priority': 'A',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '2',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'rowid': '211813229-95',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41093657380003, 37.779211684542325]},
#   ':@computed_region_ajp5_b2md': '34'},
#  {'call_number': '211813229',
#   'unit_id': 'E36',
#   'incident_number': '21077729',
#   'call_type': 'Traffic Collision',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:39:24.000',
#   'entry_dttm': '2021-06-30T20:39:24.000',
#   'dispatch_dttm': '2021-06-30T20:39:42.000',
#   'response_dttm': '2021-06-30T20:41:46.000',
#   'call_final_disposition': 'Unable to Locate',
#   'available_dttm': '2021-06-30T20:43:55.000',
#   'address': '7TH ST/MISSION ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B02',
#   'station_area': '01',
#   'box': '2315',
#   'original_priority': 'A',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '2',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'rowid': '211813229-E36',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41093657380003, 37.779211684542325]},
#   ':@computed_region_ajp5_b2md': '34'},
#  {'call_number': '211813229',
#   'unit_id': 'RS1',
#   'incident_number': '21077729',
#   'call_type': 'Traffic Collision',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:39:24.000',
#   'entry_dttm': '2021-06-30T20:39:24.000',
#   'dispatch_dttm': '2021-06-30T20:39:42.000',
#   'response_dttm': '2021-06-30T20:41:13.000',
#   'on_scene_dttm': '2021-06-30T20:43:01.000',
#   'call_final_disposition': 'Unable to Locate',
#   'available_dttm': '2021-06-30T20:44:24.000',
#   'address': '7TH ST/MISSION ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B02',
#   'station_area': '01',
#   'box': '2315',
#   'original_priority': 'A',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'RESCUE SQUAD',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '2',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'rowid': '211813229-RS1',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41093657380003, 37.779211684542325]},
#   ':@computed_region_ajp5_b2md': '34'},
#  {'call_number': '211813216',
#   'unit_id': '75',
#   'incident_number': '21077728',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:36:21.000',
#   'entry_dttm': '2021-06-30T20:36:56.000',
#   'dispatch_dttm': '2021-06-30T20:37:26.000',
#   'response_dttm': '2021-06-30T20:37:30.000',
#   'on_scene_dttm': '2021-06-30T20:42:47.000',
#   'transport_dttm': '2021-06-30T20:59:33.000',
#   'hospital_dttm': '2021-06-30T21:12:13.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-06-30T22:04:35.000',
#   'address': '600 Block of BAY ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94133',
#   'battalion': 'B01',
#   'station_area': '28',
#   'box': '1525',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'MEDIC',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '1',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'North Beach',
#   'rowid': '211813216-75',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41706768464793, 37.80524501913409]},
#   ':@computed_region_ajp5_b2md': '23'},
#  {'call_number': '211813216',
#   'unit_id': 'E28',
#   'incident_number': '21077728',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:36:21.000',
#   'entry_dttm': '2021-06-30T20:36:56.000',
#   'dispatch_dttm': '2021-06-30T20:37:26.000',
#   'response_dttm': '2021-06-30T20:38:33.000',
#   'on_scene_dttm': '2021-06-30T20:41:03.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-06-30T20:47:30.000',
#   'address': '600 Block of BAY ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94133',
#   'battalion': 'B01',
#   'station_area': '28',
#   'box': '1525',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Potentially Life-Threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '1',
#   'supervisor_district': '3',
#   'neighborhoods_analysis_boundaries': 'North Beach',
#   'rowid': '211813216-E28',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.41706768464793, 37.80524501913409]},
#   ':@computed_region_ajp5_b2md': '23'},
#  {'call_number': '211813214',
#   'unit_id': 'E01',
#   'incident_number': '21077727',
#   'call_type': 'Explosion',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:34:13.000',
#   'entry_dttm': '2021-06-30T20:36:32.000',
#   'dispatch_dttm': '2021-06-30T20:37:57.000',
#   'response_dttm': '2021-06-30T20:39:45.000',
#   'on_scene_dttm': '2021-06-30T20:41:29.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-06-30T20:43:34.000',
#   'address': '0 Block of HARRIET ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B03',
#   'station_area': '01',
#   'box': '2252',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': True,
#   'call_type_group': 'Fire',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '3',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'rowid': '211813214-E01',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.40696994408671, 37.77866179439041]},
#   ':@computed_region_ajp5_b2md': '34'},
#  {'call_number': '211813214',
#   'unit_id': 'B03',
#   'incident_number': '21077727',
#   'call_type': 'Explosion',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:34:13.000',
#   'entry_dttm': '2021-06-30T20:36:32.000',
#   'dispatch_dttm': '2021-06-30T20:37:57.000',
#   'response_dttm': '2021-06-30T20:39:57.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-06-30T20:44:03.000',
#   'address': '0 Block of HARRIET ST',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94103',
#   'battalion': 'B03',
#   'station_area': '01',
#   'box': '2252',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Fire',
#   'number_of_alarms': '1',
#   'unit_type': 'CHIEF',
#   'unit_sequence_in_call_dispatch': '2',
#   'fire_prevention_district': '3',
#   'supervisor_district': '6',
#   'neighborhoods_analysis_boundaries': 'South of Market',
#   'rowid': '211813214-B03',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.40696994408671, 37.77866179439041]},
#   ':@computed_region_ajp5_b2md': '34'},
#  {'call_number': '211813211',
#   'unit_id': 'KM11',
#   'incident_number': '21077726',
#   'call_type': 'Medical Incident',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:36:26.000',
#   'entry_dttm': '2021-06-30T20:36:26.000',
#   'dispatch_dttm': '2021-06-30T20:36:40.000',
#   'response_dttm': '2021-06-30T20:37:20.000',
#   'on_scene_dttm': '2021-06-30T20:46:19.000',
#   'transport_dttm': '2021-06-30T20:54:03.000',
#   'hospital_dttm': '2021-06-30T21:08:12.000',
#   'call_final_disposition': 'Code 2 Transport',
#   'available_dttm': '2021-06-30T21:38:53.000',
#   'address': '0 Block of TOLEDO WAY',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94123',
#   'battalion': 'B04',
#   'station_area': '16',
#   'box': '3565',
#   'original_priority': 'A',
#   'priority': '2',
#   'final_priority': '2',
#   'als_unit': False,
#   'call_type_group': 'Non Life-threatening',
#   'number_of_alarms': '1',
#   'unit_type': 'PRIVATE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '4',
#   'supervisor_district': '2',
#   'neighborhoods_analysis_boundaries': 'Marina',
#   'rowid': '211813211-KM11',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.43846546123724, 37.80119507315116]},
#   ':@computed_region_ajp5_b2md': '13'},
#  {'call_number': '211813205',
#   'unit_id': 'E22',
#   'incident_number': '21077725',
#   'call_type': 'Alarms',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:32:17.000',
#   'entry_dttm': '2021-06-30T20:34:27.000',
#   'dispatch_dttm': '2021-06-30T20:35:08.000',
#   'response_dttm': '2021-06-30T20:36:15.000',
#   'on_scene_dttm': '2021-06-30T20:38:42.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-06-30T21:08:25.000',
#   'address': '0 Block of HAGIWARA TEA GARDEN DR',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94118',
#   'battalion': 'B07',
#   'station_area': '22',
#   'box': '7742',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'ENGINE',
#   'unit_sequence_in_call_dispatch': '1',
#   'fire_prevention_district': '7',
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Golden Gate Park',
#   'rowid': '211813205-E22',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.46830096819892, 37.770958280725445]},
#   ':@computed_region_ajp5_b2md': '12'},
#  {'call_number': '211813205',
#   'unit_id': 'T14',
#   'incident_number': '21077725',
#   'call_type': 'Alarms',
#   'call_date': '2021-06-30T00:00:00.000',
#   'watch_date': '2021-06-30T00:00:00.000',
#   'received_dttm': '2021-06-30T20:32:17.000',
#   'entry_dttm': '2021-06-30T20:34:27.000',
#   'dispatch_dttm': '2021-06-30T20:35:08.000',
#   'response_dttm': '2021-06-30T20:36:09.000',
#   'call_final_disposition': 'Fire',
#   'available_dttm': '2021-06-30T20:37:03.000',
#   'address': '0 Block of HAGIWARA TEA GARDEN DR',
#   'city': 'San Francisco',
#   'zipcode_of_incident': '94118',
#   'battalion': 'B07',
#   'station_area': '22',
#   'box': '7742',
#   'original_priority': '3',
#   'priority': '3',
#   'final_priority': '3',
#   'als_unit': False,
#   'call_type_group': 'Alarm',
#   'number_of_alarms': '1',
#   'unit_type': 'TRUCK',
#   'unit_sequence_in_call_dispatch': '3',
#   'fire_prevention_district': '7',
#   'supervisor_district': '1',
#   'neighborhoods_analysis_boundaries': 'Golden Gate Park',
#   'rowid': '211813205-T14',
#   'case_location': {'type': 'Point',
#    'coordinates': [-122.46830096819892, 37.770958280725445]},
#   ':@computed_region_ajp5_b2md': '12'},
#  ...]

# %%
from pyspark.sql.types import *

fire_schema = StructType([StructField('call_number', StringType(), True),
                StructField('unit_id', StringType(), True),
                StructField('incident_number', StringType(), True),
                StructField('call_type', StringType(), True),
                StructField('call_date', StringType(), True),
                StructField('watch_date', StringType(), True),
                StructField('call_final_disposition', StringType(), True),
                StructField('available_dttm', StringType(), True),
                StructField('address', StringType(), True),
                StructField('city', StringType(), True),
                StructField('zipcode_of_incident', StringType(), True),
                StructField('battalion', StringType(), True),
                StructField('station_area', StringType(), True),
                StructField('box', StringType(), True),
                StructField('original_priority', StringType(), True),
                StructField('priority', StringType(), True),
                StructField('final_priority', StringType(), True),
                StructField('als_unit', BooleanType(), True),
                StructField('call_type_group', StringType(), True),
                StructField('number_of_alarms', StringType(), True),
                StructField('unit_type', StringType(), True),
                StructField('unit_sequence_in_call_dispatch', StringType(), True),
                StructField('fire_prevention_district', StringType(), True),
                StructField('supervisor_district', StringType(), True),
                StructField('neighborhoods_analysis_boundaries', StringType(), True),
                StructField('case_location', StructType([
                    StructField('type', StringType(), True),
                    StructField('coordinates', ArrayType(FloatType()), True),
                                                            ]), True),
                StructField('rowid', StringType(), True)])

# %%
fireDF = spark.createDataFrame(results, fire_schema)

# %%
fireDF.show(6, False)
# Out:
# 23/05/09 19:43:27 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 23/05/09 19:43:27 WARN TaskSetManager: Stage 0 contains a task of very large size (1946 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 0:>                                                          (0 + 1) / 1]
# +-----------+-------+---------------+------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------------+-------------+-------------------+---------+------------+----+-----------------+--------+--------------+--------+---------------+----------------+---------+------------------------------+------------------------+-------------------+---------------------------------+---------------------------------+-------------+
# |call_number|unit_id|incident_number|call_type   |call_date              |watch_date             |call_final_disposition|available_dttm         |address                    |city         |zipcode_of_incident|battalion|station_area|box |original_priority|priority|final_priority|als_unit|call_type_group|number_of_alarms|unit_type|unit_sequence_in_call_dispatch|fire_prevention_district|supervisor_district|neighborhoods_analysis_boundaries|case_location                    |rowid        |
# +-----------+-------+---------------+------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------------+-------------+-------------------+---------+------------+----+-----------------+--------+--------------+--------+---------------+----------------+---------+------------------------------+------------------------+-------------------+---------------------------------+---------------------------------+-------------+
# |221210313  |E36    |22054955       |Outside Fire|2022-05-01T00:00:00.000|2022-04-30T00:00:00.000|Fire                  |2022-05-01T03:05:00.000|GOUGH ST/GROVE ST          |San Francisco|94102              |B02      |36          |3265|3                |3       |3             |true    |Fire           |1               |ENGINE   |1                             |2                       |5                  |Hayes Valley                     |{Point, [-122.423164, 37.777817]}|221210313-E36|
# |220190150  |E29    |22008871       |Alarms      |2022-01-19T00:00:00.000|2022-01-18T00:00:00.000|Fire                  |2022-01-19T02:35:26.000|100 Block of MISSISSIPPI ST|San Francisco|94107              |B03      |29          |2431|3                |3       |3             |true    |Alarm          |1               |ENGINE   |1                             |3                       |10                 |Potrero Hill                     |{Point, [-122.3947, 37.76461]}   |220190150-E29|
# |211233271  |T07    |21053032       |Alarms      |2021-05-03T00:00:00.000|2021-05-03T00:00:00.000|Fire                  |2021-05-03T21:38:09.000|0 Block of HOFF ST         |San Francisco|94110              |B02      |07          |5236|A                |3       |3             |false   |Alarm          |1               |TRUCK    |2                             |2                       |9                  |Mission                          |{Point, [-122.42058, 37.764183]} |211233271-T07|
# |212933533  |B02    |21127914       |Alarms      |2021-10-20T00:00:00.000|2021-10-20T00:00:00.000|Fire                  |2021-10-20T22:25:52.000|200 Block of JONES ST      |San Francisco|94102              |B03      |03          |1456|3                |3       |3             |false   |Alarm          |1               |CHIEF    |3                             |3                       |6                  |Tenderloin                       |{Point, [-122.41244, 37.783478]} |212933533-B02|
# |221202543  |E41    |22054815       |Alarms      |2022-04-30T00:00:00.000|2022-04-30T00:00:00.000|Fire                  |2022-04-30T18:40:08.000|1400 Block of FILBERT ST   |San Francisco|94109              |B04      |16          |3146|3                |3       |3             |false   |Alarm          |1               |ENGINE   |4                             |4                       |2                  |Russian Hill                     |{Point, [-122.42334, 37.799534]} |221202543-E41|
# |211232439  |B01    |21052945       |Alarms      |2021-05-03T00:00:00.000|2021-05-03T00:00:00.000|Fire                  |2021-05-03T17:05:20.000|500 Block of JONES ST      |San Francisco|94102              |B01      |03          |1462|3                |3       |3             |false   |Alarm          |1               |CHIEF    |2                             |1                       |6                  |Tenderloin                       |{Point, [-122.412994, 37.78627]} |211232439-B01|
# +-----------+-------+---------------+------------+-----------------------+-----------------------+----------------------+-----------------------+---------------------------+-------------+-------------------+---------+------------+----+-----------------+--------+--------------+--------+---------------+----------------+---------+------------------------------+------------------------+-------------------+---------------------------------+---------------------------------+-------------+
# only showing top 6 rows

# %%
fireDF.printSchema()
# Out:
# root
#  |-- call_number: string (nullable = true)
#  |-- unit_id: string (nullable = true)
#  |-- incident_number: string (nullable = true)
#  |-- call_type: string (nullable = true)
#  |-- call_date: string (nullable = true)
#  |-- watch_date: string (nullable = true)
#  |-- call_final_disposition: string (nullable = true)
#  |-- available_dttm: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- zipcode_of_incident: string (nullable = true)
#  |-- battalion: string (nullable = true)
#  |-- station_area: string (nullable = true)
#  |-- box: string (nullable = true)
#  |-- original_priority: string (nullable = true)
#  |-- priority: string (nullable = true)
#  |-- final_priority: string (nullable = true)
#  |-- als_unit: boolean (nullable = true)
#  |-- call_type_group: string (nullable = true)
#  |-- number_of_alarms: string (nullable = true)
#  |-- unit_type: string (nullable = true)
#  |-- unit_sequence_in_call_dispatch: string (nullable = true)
#  |-- fire_prevention_district: string (nullable = true)
#  |-- supervisor_district: string (nullable = true)
#  |-- neighborhoods_analysis_boundaries: string (nullable = true)
#  |-- case_location: struct (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: float (containsNull = true)
#  |-- rowid: string (nullable = true)

# %%
parquet_path = "./data/5-Fire_Calls"
fireDF.write.format("parquet").save(parquet_path)
# Out:
# 23/05/09 19:43:29 WARN TaskSetManager: Stage 1 contains a task of very large size (1946 KiB). The maximum recommended task size is 1000 KiB.

# %%
parquet_table = "Fire_Calls_Table"
fireDF.write.format("parquet").saveAsTable(parquet_table)
# Out:
# 23/05/09 19:43:31 WARN TaskSetManager: Stage 2 contains a task of very large size (1946 KiB). The maximum recommended task size is 1000 KiB.
